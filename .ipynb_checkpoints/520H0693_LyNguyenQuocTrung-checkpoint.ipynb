# %%
import nltk
import re
from nltk import ngrams
from collections import Counter

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\quoct\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
filename = 'train.txt'
with open(filename, encoding = 'utf-8') as f:
  lines = f.readlines()
print(lines)
# Out:
# ["Here are two reasons companies fail: they only do more of the same, or they only do what's new\n", 'To me the real, real solution to quality growth is figuring out the balance between two activities: exploration and exploitation\n', ' Both are necessary, but it can be too much of a good thing\n', 'Consider Facit\n', " I'm actually old enough to remember them\n", ' Facit was a fantastic company\n', ' Everybody used them\n', ' And what did Facit do when the electronic calculator came along? They continued doing exactly the same\n', ' In six months, they went from maximum revenue \n', ' and they were gone\n', ' Gone\n', 'To me, the irony about the Facit story is hearing about the Facit engineers, who had bought cheap, small electronic calculators in Japan that they used to double-check their calculators\n', 'Facit did too much exploitation\n', ' But exploration can go wild, too\n', " Let's call them OncoSearch\n", ' The company was brilliant\n', ' They had applications that promised t
# ...

# %%
counter_bigram = Counter()
for sent in lines:
  tokens = nltk.word_tokenize(sent.lower())
  tokens = ['<s>'] + tokens
  gram2 = ngrams(tokens,2)
  join_grams = ['_'.join(list(gram)) for gram in gram2]
  counter_bigram.update(join_grams)
print(len(counter_bigram))
print(counter_bigram.most_common(10))
# Out:
# 111438
# [(',_and', 2308), ('<s>_and', 2169), ('of_the', 1363), ('in_the', 1357), ("it_'s", 1205), ('<s>_i', 1178), ('<s>_so', 1120), (',_i', 977), (',_the', 965), ('<s>_it', 885)]

# %%
counter_unigram = Counter()
for sent in lines:
  tokens = nltk.word_tokenize(sent.lower())
  tokens = ['<s>'] + tokens
  gram2 = ngrams(tokens,1)
  join_grams = ['_'.join(list(gram)) for gram in gram2]
  counter_unigram.update(join_grams)
print(len(counter_unigram))

V = len(counter_unigram)
print(counter_unigram.most_common(10))

total = 0
for i in counter_unigram.values():
  total +=i
print(total)
# Out:
# 16681
# [(',', 19071), ('<s>', 16382), ('the', 13061), ('and', 9306), ('to', 8222), ('of', 7082), ('a', 6577), ('that', 5681), ('i', 5302), ('in', 4981)]
# 321771

# %%
def Psent(sent):
  prob = 1
  alpha =1.01
  tokens = nltk.word_tokenize(sent.lower())
  tokens = ['<s>'] +tokens
  for i in range(1,len(tokens)):
    prob *= ((counter_bigram[tokens[i-1]+'_'+tokens[i]])+alpha)/((counter_unigram[tokens[i-1]])+V*alpha)
  return prob

# %%
def uniPsent(sent):
  prob = 1
  alpha =1.01
  tokens = nltk.word_tokenize(sent.lower())
  tokens = ['<s>'] +tokens
  for i in range(len(tokens)):
    prob *= ((counter_bigram[tokens[i]])+alpha)/(total+(V*alpha))
  return prob

# %%
text = "i like a book"
text2 = "i like a famous book"
print(Psent(text))
print(Psent(text2))
print(uniPsent(text))
# Out:
# 8.581388765582192e-11
# 2.8043367919752863e-15
# 2.3607580168295835e-28
